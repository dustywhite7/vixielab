# %%
from __future__ import division
import pandas as pd
import numpy as np
import sklearn as sk

data = pd.read_csv('StudentLoanSimulatedData.csv')

# vars[0] is % of ParentsIncome dedicated to all of their children's educations
# vars[1] is # of hours worked by student per year
# vars[2] is education baseline (must be > 0)
# vars[3] is impact of grades on scholarship
# vars[4] is the negative impact of ParentsIncome on scholarship eligibility
vars = np.array([.15, 2000, 1, .25, .1])
N = 1000

def studentLoanData(vars,N):

    randMat = np.array(np.random.uniform(0,1,[N,20]))
    ParentsIncome = randMat[:,0]*100000
    NumberOfSiblings = np.floor(randMat[:,1]*10)
    ParentsPortion = np.divide(ParentsIncome*vars[0],1+NumberOfSiblings)

    WorkExperience = np.floor(randMat[:,2]*8)
    Education = np.floor(randMat[:,3]*2)
    Skills = np.floor(randMat[:,4]*4)
    MinimumWage = np.floor(randMat[:,5]*20)
    StudentIncome = vars[1]*MinimumWage+np.multiply(WorkExperience,Education+vars[2],Skills)

    Years = np.floor(randMat[:,6]*8)
    College = randMat[:,7]*10000
    InState = np.floor(randMat[:,8]*2)
    Tuition = np.multiply(Years,College,InState+1)

    Grades =  np.floor(randMat[:,9]*40)/10
    Scholarship = np.multiply(vars[3]*Grades,Tuition - vars[4]*ParentsIncome)
    Scholarship = Scholarship.clip(0)

    State = randMat[:,10]*15000
    Roomies = np.floor(randMat[:,11]*10)
    BlingFactor = np.floor(randMat[:,12]*9)
    LivingExpenses = np.divide(np.multiply(State,1+BlingFactor),1+Roomies)

    Materials = randMat[:,13]*5000

    StudentLoanAmount = ParentsPortion + StudentIncome + Scholarship - Tuition - LivingExpenses - Materials
    Loans = (StudentLoanAmount<0)
    Loans = Loans.astype(int)

    NumberOfSiblings
    StudentIncome

    data = pd.DataFrame.from_items([('Loans', Loans), ('ParentsIncome', ParentsIncome), 
                                    ('WorkExperience', WorkExperience), ('Education', Education), 
                                    ('MinimumWage', MinimumWage), ('Grades', Grades), 
                                    ('Tuition', Tuition), ('Years', Years), ('College', College), 
                                    ('InState', InState), ('BlingFactor', BlingFactor), 
                                    ('NumberOfSiblings', NumberOfSiblings), ('State', State), ('Materials', Materials)])


def histogramClass(data, maxgrid = 2):
    if (str(type(data)) == "<class 'pandas.core.frame.DataFrame'>"):
        nrow, ncol = np.shape(data)

        histogram = pd.DataFrame(np.zeros((nrow,ncol)))
        classifier = pd.DataFrame()
        bins = np.arange(0,1, 1/maxgrid)

        ##### Create grid lines
        for i in range(ncol):
            colmin = min(data.ix[:,i])
            colmax = max(data.ix[:,i])
            data.ix[:,i] = (data.ix[:,i]-colmin)/colmax

            if i>0:
                histogram.ix[:,i] = np.digitize(data.ix[:,i],bins)
            else:
                histogram.ix[:,i] = data.ix[:,i]

        ##### Store rows of histogram that predict "output = 1"
        for i in histogram.groupby(list(histogram.columns)[1:])[0]:
            print i


        return histogram
    else:
        print "Incorrect Data Type - Data should be in Pandas DataFrame."
# Out:
#   File "<ipython-input-2-4f9a397e0d7d>", line 12
#     def histogramClass(data, maxgrid = 2):
#       ^
# IndentationError: expected an indented block

# %%
from __future__ import division
import numpy as np
import pandas as pd

vars = np.array([.15, 2000, 1, .25, .1])
N = 10

randMat = np.array(np.random.uniform(0,1,[N,20]))
ParentsIncome = randMat[:,0]*100000
NumberOfSiblings = np.floor(randMat[:,1]*10)
ParentsPortion = np.divide(ParentsIncome*vars[0],1+NumberOfSiblings)

WorkExperience = np.floor(randMat[:,2]*8)
Education = np.floor(randMat[:,3]*2)
Skills = np.floor(randMat[:,4]*4)
MinimumWage = np.floor(randMat[:,5]*20)
StudentIncome = vars[1]*MinimumWage+np.multiply(WorkExperience,Education+vars[2],Skills)

Years = np.floor(randMat[:,6]*8)
College = randMat[:,7]*10000
InState = np.floor(randMat[:,8]*2)
Tuition = np.multiply(Years,College,InState+1)

Grades =  np.floor(randMat[:,9]*40)/10
Scholarship = np.multiply(vars[3]*Grades,Tuition - vars[4]*ParentsIncome)
Scholarship = Scholarship.clip(0)

State = randMat[:,10]*15000
Roomies = np.floor(randMat[:,11]*10)
BlingFactor = np.floor(randMat[:,12]*9)
LivingExpenses = np.divide(np.multiply(State,1+BlingFactor),1+Roomies)

Materials = randMat[:,13]*5000

StudentLoanAmount = ParentsPortion + StudentIncome + Scholarship - Tuition - LivingExpenses - Materials
Loans = (StudentLoanAmount<0)
Loans = Loans.astype(int)

NumberOfSiblings
StudentIncome

data = pd.DataFrame.from_items([('Loans', Loans), ('ParentsIncome', ParentsIncome), 
                                ('WorkExperience', WorkExperience), ('Education', Education), 
                                ('MinimumWage', MinimumWage), ('Grades', Grades), 
                                ('Tuition', Tuition), ('Years', Years), ('College', College), 
                                ('InState', InState), ('BlingFactor', BlingFactor), 
                                ('NumberOfSiblings', NumberOfSiblings), ('State', State), ('Materials', Materials)])
#data = pd.DataFrame(Loans,index = len(Loans),columns ="Loans")

# %%
type(Loans)
print type(Loans[0])
np.bincount(Loans)
data
# Out:
# <type 'numpy.int32'>
#    Loans  ParentsIncome  WorkExperience  Education  MinimumWage  Grades  \
# 0      1   38208.199852               2          1            1     0.1
# 1      1   67866.672853               4          1           15     2.1
# 2      1   14110.977646               0          1           19     1.2
# 3      0   39665.853916               1          1           16     1.6
# 4      1   60216.881642               4          0            4     1.6
# 5      0   60925.425113               5          0           17     0.1
# 6      1   44187.609046               6          0           17     2.5
# 7      0   58670.005143               5          1           12     0.0
# 8      0   78509.781715               6          1           14     1.7
# 9      1   21383.762820               3          0            4     1.3
#
#         Tuition  Years      College  InState  BlingFactor  NumberOfSiblings  \
# 0  16877.499035      4  4219.374759        1            1                 5
# 1  62702.776870      7  8957.539553        1            8                 7
# 2  39019.156628      6  6503.192771        0            5                 3
# 3   1534.283291      1  1534.283291        1            0                 2
# 4   4833.306568      6   805.551095        0            8                 5
# 5   6583.304852      3  2194.434951        0            2                 2
# 6  30033.005398      6  5005.500900        0            7                 8
# 7      0.000000      0  5478.782599        0            6                 4
# 8   6485.864231      7   926.552033        0            5                 8
# 9  22250.108256      4  5562.527064        1            1                 3
#
#           State    Materials
# 0  12778.830086  2196.416108
# 1  11161.854828   778.192687
# 2   9522.070619  2933.859108
# 3   2228.855057  2284.473613
# 4  10549.180337  2456.709407
# 5   3713.481982  1993.600715
# 6   2783.966271  3207.276577
# 7   3740.078524  2419.427152
# 8    407.674644  1982.476717
# 9  11687.596886  3227.362958

# %%
#Troubleshooting array changes for Grades
#
#Compare the troublesome first line to the corrected second:
#Scholarship = np.multiply(vars[3],Grades,Tuition - vars[4]*ParentsIncome)
#Scholarship = np.multiply(vars[3]*Grades,Tuition - vars[4]*ParentsIncome)
#The first line changes the Grades array to equal the Scholarship array.

Grades =  np.floor(randMat[:,9]*40)/10
print vars[3]
print Grades
var1 = vars[3]*Grades
print ""

print vars[4]
print ParentsIncome
print Tuition
var2 = Tuition - vars[4]*ParentsIncome
print ""

Scholarship = np.multiply(var1,var2)
print Scholarship
Scholarship = np.multiply(vars[3]*Grades,Tuition - vars[4]*ParentsIncome)
print Scholarship
print Grades

print np.corrcoef(Scholarship,Grades)
print np.corrcoef(Scholarship,Tuition)
print np.corrcoef(Scholarship,ParentsIncome)
# Out:
# 0.25
# [ 0.7  1.9  2.2  2.   2.   3.5  0.6  0.6  3.8  0.2]
#
# 0.1
# [ 70291.34892352  24287.34786823  94510.44681296  79524.55773913
#   34623.79290463  46053.82643722  42569.0633275    2050.34557395
#   15798.91178017  19323.73437017]
# [     0.              0.          40046.03682264    160.25678846
#    8239.148146        0.          25474.08143788  26516.29533332
#   36443.23653981  15154.13956315]
#
# [ -1230.09860616  -1153.64902374  16827.24567774  -3896.09949273
#    2388.38442777  -4029.70981326   3182.57626577   3946.68911639
#   33120.1780937     661.08830631]
# [ -1230.09860616  -1153.64902374  16827.24567774  -3896.09949273
#    2388.38442777  -4029.70981326   3182.57626577   3946.68911639
#   33120.1780937     661.08830631]
# [ 0.7  1.9  2.2  2.   2.   3.5  0.6  0.6  3.8  0.2]
# [[ 1.          0.46671938]
#  [ 0.46671938  1.        ]]
# [[ 1.          0.81152663]
#  [ 0.81152663  1.        ]]
# [[ 1.         -0.12634877]
#  [-0.12634877  1.        ]]
